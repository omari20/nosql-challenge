# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# Import the dataset with: `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'class_db', 'config', 'epa', 'fruits_db', 'local', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65ff9d98378cd3aa4ff9af36'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_restaurant)
# Out:
# InsertOneResult(ObjectId('66035b49347b841b6c67a2de'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(query)

for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65ff9e03311f2e13e3c86692'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'latitude': None,
#  'longitude': None,
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6601da67649ac83e50f07d18'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'latitude': None,
#  'longitude': None,
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66035b49347b841b6c67a2de'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen' }
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# Capture the results to a variable
results = establishments.find(query, fields)

# # pretty print all results
# for result in results:
#     pprint(result)
pprint(results[1])
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65ff9d98378cd3aa4ff9af43')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {'BusinessName':'Penang Flavours'},
    {'$set': 
     {'BusinessTypeID': 1}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
result = db.establishments.find(query)

for i in result:
    pprint(i)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65ff9e03311f2e13e3c86692'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'latitude': None,
#  'longitude': None,
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6601da67649ac83e50f07d18'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'latitude': None,
#  'longitude': None,
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66035b49347b841b6c67a2de'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': {'$regex':'Dover'}}
result = db.establishments.count_documents(query)

print(result)
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
db.establishments.delete_many(query)
# Out:
# DeleteResult({'n': 0, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
db.establishments.count_documents(query)
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
db.establishments.find_one()
# Out:
# {'_id': ObjectId('65ff9d98378cd3aa4ff9af36'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}],
#  'latitude': None,
#  'longitude': None}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
db.establishments.update_many({},[ {'$set': {
                                'latitude': {'$toDouble': '$latitude'},
                                'longitude': {'$toDouble': '$longitude'}}
                                }])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
db.establishments.update_many(
    {}, [ {'$set': {'RatingValue': {'$toInt': '$RatingValue'}}} ])
# Out:
# UpdateResult({'n': 38787, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers

# Iterate over every document in the collection
for document in db.establishments.find():
    # Get the document's _id
    document_id = document.get('_id')
    
    # Check if the field exists and its type is integer
    if isinstance(document.get('RatingValue'), int):
        print(f"RatingValue in document {document_id} is an integer.")
    else:
        print(f"RatingValue in document {document_id} is not an integer.")
# Out:
# RatingValue in document 65ff9d98378cd3aa4ff9af36 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af38 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af39 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af3c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af3d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af3e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af3f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af40 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af42 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af43 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af44 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af45 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af46 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af47 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af48 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af49 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af4f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af50 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af51 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af52 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af53 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af54 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af55 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af56 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af57 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af58 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af59 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af5a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af5b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af5c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af5d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af5e is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af61 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af63 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af65 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af68 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af69 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af6c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af6d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af6e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af6f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af71 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af72 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af73 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af74 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af75 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af76 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af7c is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af7d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af7e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af80 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af83 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af84 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af85 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af87 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af88 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af89 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af8f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af90 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af91 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af92 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af93 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af94 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af95 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af96 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af97 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af98 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af99 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9af9f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa1 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afa9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afaa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afab is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afac is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afad is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afae is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afaf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb6 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afb9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afba is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afbb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afbc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afbd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afbe is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afbf is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afc9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afca is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afcb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afcc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afcd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afcf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd1 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd4 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afd9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afda is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afdb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afdc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afdd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe7 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afe9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afea is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afeb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afec is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afed is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afef is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff5 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9aff9 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9affa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9affb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9affc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9affd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9affe is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9afff is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b000 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b001 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b002 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b003 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b005 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b006 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b007 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b008 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b009 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b00f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b010 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b011 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b012 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b013 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b014 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b015 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b016 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b017 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b018 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b019 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b01f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b020 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b021 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b022 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b023 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b024 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b025 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b026 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b027 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b028 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b029 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b02f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b030 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b031 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b032 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b033 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b034 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b035 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b036 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b037 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b038 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b039 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b03f is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b040 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b041 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b042 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b043 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b044 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b045 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b047 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b048 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b049 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04e is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b04f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b050 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b051 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b052 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b053 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b054 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b055 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b056 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b057 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b058 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b059 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b05f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b060 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b061 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b062 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b063 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b064 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b065 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b066 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b067 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b068 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b069 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b06f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b070 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b071 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b072 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b073 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b074 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b075 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b076 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b077 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b078 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b079 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b07a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b07b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b07c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b07f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b080 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b081 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b082 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b083 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b084 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b085 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b086 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b087 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b088 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b089 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b08f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b090 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b091 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b093 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b095 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b098 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b09a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b09b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b09c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b09d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0a9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0aa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ab is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ac is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ad is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0af is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0b9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ba is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0bb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0bc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0bd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0be is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0bf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0c9 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0cb is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0cc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0cd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ce is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0cf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0d9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0db is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0dc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0dd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0de is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0df is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0e9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ea is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0eb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ec is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ed is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ee is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ef is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0f9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0fa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0fb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0fc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0fd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0fe is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b0ff is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b100 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b101 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b102 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b103 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b104 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b105 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b106 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b107 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b108 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b109 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b10f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b110 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b111 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b112 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b113 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b114 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b116 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b117 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b118 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b11a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b11b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b11d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b11e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b120 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b121 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b122 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b123 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b124 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b125 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b127 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b128 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b129 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b12f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b130 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b131 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b132 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b133 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b134 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b135 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b136 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b137 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b139 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b13f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b140 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b141 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b142 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b143 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b144 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b145 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b146 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b147 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b148 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b149 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b14f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b150 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b151 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b152 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b153 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b154 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b155 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b156 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b157 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b158 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b159 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b15f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b160 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b161 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b162 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b163 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b164 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b165 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b166 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b167 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b168 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b169 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b16f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b170 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b171 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b172 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b173 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b174 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b175 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b176 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b177 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b178 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b179 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b17f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b180 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b181 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b182 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b183 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b184 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b185 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b186 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b187 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b188 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b189 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18d is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b18f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b190 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b191 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b192 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b193 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b194 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b195 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b196 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b197 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b198 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b199 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b19f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a3 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1a9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1aa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ab is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ac is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ad is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ae is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1af is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1b9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ba is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1bc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1bd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1be is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1bf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1c9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ca is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1cb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1cc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1cd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ce is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1cf is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1d9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1da is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1db is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1dc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1dd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1de is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1df is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e6 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e7 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1e9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ea is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1eb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ec is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ed is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ee is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ef is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f0 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f1 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f2 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f3 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f4 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f5 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f6 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f7 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f8 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1f9 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1fa is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1fb is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1fc is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1fd is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1fe is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b1ff is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b200 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b201 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b202 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b203 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b204 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b205 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b206 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b207 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b208 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b209 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b20a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b20b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b20d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b20e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b20f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b210 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b211 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b212 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b213 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b214 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b215 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b216 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b217 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b218 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b219 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b21f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b220 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b221 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b222 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b223 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b224 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b225 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b226 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b227 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b228 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b229 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22d is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b22f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b230 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b232 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b234 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b235 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b236 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b237 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b239 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23b is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b23f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b240 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b242 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b243 is not an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b245 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b246 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b247 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b249 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b24a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b24b is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b24c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b24e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b24f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b250 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b251 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b252 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b253 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b254 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b255 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b256 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b257 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b258 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b259 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b25a is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b25c is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b25d is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b25e is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b25f is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b260 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b261 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b262 is an integer.
# RatingValue in document 65ff9d98378cd3aa4ff9b263 is an integer.
# ...
# RatingValue in document 65ff9d99378cd3aa4ffa46cc is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46cd is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ce is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46cf is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d0 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d1 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d2 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d3 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d4 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d5 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d6 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d7 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d8 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46d9 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46da is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46db is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46dc is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46dd is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46de is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46df is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e0 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e1 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e2 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e3 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e4 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e5 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e6 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e7 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e8 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46e9 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ea is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46eb is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ec is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ed is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ee is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ef is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f0 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f1 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f2 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f3 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f4 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f5 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f6 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f7 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f8 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46f9 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46fa is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46fb is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46fc is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46fd is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46fe is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa46ff is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4700 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4701 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4702 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4703 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4704 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4705 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4706 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4707 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4708 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4709 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470e is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa470f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4710 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4711 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4712 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4713 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4714 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4715 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4716 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4717 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4718 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4719 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471e is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa471f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4720 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4721 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4722 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4723 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4724 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4725 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4726 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4727 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4728 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4729 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472d is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa472f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4730 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4731 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4732 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4733 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4734 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4735 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4736 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4737 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4738 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4739 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473c is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa473f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4740 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4741 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4742 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4743 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4744 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4745 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4746 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4747 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4748 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4749 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474b is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474e is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa474f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4750 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4751 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4752 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4753 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4754 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4755 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4756 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4757 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4758 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4759 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa475f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4760 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4761 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4762 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4763 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4764 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4765 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4766 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4767 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4768 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4769 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476b is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa476f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4770 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4771 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4772 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4773 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4774 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4775 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4776 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4777 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4778 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4779 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477d is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477e is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa477f is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4780 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4781 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4782 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4783 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4784 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4785 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4786 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4787 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4788 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4789 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478a is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478d is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa478f is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4790 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4791 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4792 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4793 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4794 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4795 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4796 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4797 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4798 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa4799 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479a is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479b is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479c is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479d is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479e is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa479f is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a0 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a1 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a2 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a3 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a4 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a5 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a6 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a7 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a8 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47a9 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47aa is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47ab is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47ac is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47ad is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47ae is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47af is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b0 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b1 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b2 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b3 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b4 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b5 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b6 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b7 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b8 is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47b9 is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47ba is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47bb is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47bc is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47bd is not an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47be is an integer.
# RatingValue in document 65ff9d99378cd3aa4ffa47bf is an integer.
# RatingValue in document 65ff9e03311f2e13e3c86692 is not an integer.
# RatingValue in document 6601da67649ac83e50f07d18 is not an integer.
